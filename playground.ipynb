# %%
import pandas

# %%
df1 = pandas.read_csv(r'D:\NPMDAuto\docs\weekly-all-user-activities.csv', sep='\t')

# %%
df1
# Out:
#          User  , First Name ,.1    Last Name ,.2              User Mail ID  \
# 0       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 1       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 2       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 3       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 4       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 5       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 6       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 7       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 8       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 9       admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# 10      admin  ,        Sev   ,          One   ,    gsnpmd.contract@bt.com
# ...

# %%
df2 = pandas.read_excel(r'D:\NPMDAuto\docs\weekly-all-user-activities.xlsx')

# %%
df2
# Out:
#      UserName\t \tFirst Name\t    \tLast Name\t                       \tEMail  \
# 0       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 1       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 2       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 3       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 4       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 5       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 6       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 7       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 8       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 9       admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# 10      admin\t        \tSev\t          \tOne\t    \tgsnpmd.contract@bt.com\t
# ...

# %%
df3 = pandas.read_csv('http://sharecsv.com/dl/12746a9d2a580c502de45dd2994d331b/traffic.csv')
df3
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df4 = pandas.read_csv('https://bit.ly/2UCcoZo', sep=';')
df4
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df4.loc[1, 'Date' : 'Visitors']
# Out:
# Date          2
# Visitors    700
# Name: 1, dtype: object

# %%
df4.drop('Visitors', 1)             # 1 for column
df4.drop(4, 0)                      # 0 for row
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df4.drop(df4.columns[4], 1)             # columns[] and 1 for column
df4.drop(df4.index[7], 0)               # index[] and 0 for rows
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df4['status'] = ['Ishaan'] * df4.shape[0]
df4
# Out:
#    Date  Visitors  BR    Country  Clicks        Day  status
# 0     1      1500  20        USA      20    Tuesday  Ishaan
# 1     2       700  25         UK      35  Wednesday  Ishaan
# 2     3       900  15      India      37   Thursday  Ishaan
# 3     4       400  35        USA      12     Friday  Ishaan
# 4     5       500  14     Canada      35   Saturday  Ishaan
# 5     6       700  15      India      32     Sunday  Ishaan
# 6     7       600  20      India      37     Monday  Ishaan
# 7     8       700  16        USA      40    Tuesday  Ishaan
# 8     9      1200  27        USA      52  Wednesday  Ishaan
# 9    10      1400  32  Australia      57   Thursday  Ishaan

# %%
df5 = df4.T
df5['10'] = [11, 1400, 30, 'India', 47, 'Tuesday']

# %%
df4 = df5.T

# %%
df4
# Out:
#    Date Visitors  BR    Country Clicks        Day
# 0     1     1500  20        USA     20    Tuesday
# 1     2      700  25         UK     35  Wednesday
# 2     3      900  15      India     37   Thursday
# 3     4      400  35        USA     12     Friday
# 4     5      500  14     Canada     35   Saturday
# 5     6      700  15      India     32     Sunday
# 6     7      600  20      India     37     Monday
# 7     8      700  16        USA     40    Tuesday
# 8     9     1200  27        USA     52  Wednesday
# 9    10     1400  32  Australia     57   Thursday
# 10   11     1400  30      India     47    Tuesday
